# %%
#Ensures that the latest version of semantic-link libraries are loaded
# %pip install -U semantic-link

# %pip install -U semantic-link-labs
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 9, Finished, Available, Finished, False)
# Collecting semantic-link
#   Downloading semantic_link-0.14.1-py3-none-any.whl.metadata (20 kB)
# Collecting semantic-link-sempy==0.14.1 (from semantic-link)
#   Downloading semantic_link_sempy-0.14.1-py3-none-any.whl.metadata (21 kB)
# Collecting semantic-link-functions-geopandas==0.14.1 (from semantic-link)
#   Downloading semantic_link_functions_geopandas-0.14.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting semantic-link-functions-holidays==0.14.1 (from semantic-link)
#   Downloading semantic_link_functions_holidays-0.14.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting semantic-link-functions-meteostat==0.14.1 (from semantic-link)
#   Downloading semantic_link_functions_meteostat-0.14.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting semantic-link-functions-phonenumbers==0.14.1 (from semantic-link)
#   Downloading semantic_link_functions_phonenumbers-0.14.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting semantic-link-functions-validators==0.14.1 (from semantic-link)
#   Downloading semantic_link_functions_validators-0.14.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting geopandas (from semantic-link-functions-geopandas==0.14.1->semantic-link)
#   Downloading geopandas-1.1.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting folium (from semantic-link-functions-geopandas==0.14.1->semantic-link)
#   Downloading folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting mapclassify (from semantic-link-functions-geopandas==0.14.1->semantic-link)
#   Downloading mapclassify-2.10.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: holidays in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-functions-holidays==0.14.1->semantic-link) (0.48)
# Collecting meteostat (from semantic-link-functions-meteostat==0.14.1->semantic-link)
#   Downloading meteostat-2.1.4-py3-none-any.whl.metadata (5.2 kB)
# Collecting phonenumbers (from semantic-link-functions-phonenumbers==0.14.1->semantic-link)
#   Downloading phonenumbers-9.0.29-py2.py3-none-any.whl.metadata (10 kB)
# Collecting validators (from semantic-link-functions-validators==0.14.1->semantic-link)
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: clr_loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (0.2.5)
# Collecting fabric-analytics-sdk<1.0.0,>=0.0.3 (from semantic-link-sempy==0.14.1->semantic-link)
#   Downloading fabric_analytics_sdk-0.0.3.post1-py3-none-any.whl.metadata (14 kB)
# Collecting fabric-analytics-notebook-plugin<1.0.0,>=0.0.3 (from semantic-link-sempy==0.14.1->semantic-link)
#   Downloading fabric_analytics_notebook_plugin-0.0.3.post4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (0.20.1)
# Requirement already satisfied: azure-storage-blob>=12.18.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (12.22.0)
# Requirement already satisfied: azure-core>=1.29.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (2024.9.1)
# Collecting azure-keyvault-secrets>=4.7.0 (from semantic-link-sempy==0.14.1->semantic-link)
#   Downloading azure_keyvault_secrets-4.11.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: azure-storage-file-datalake>=12.12.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (12.16.0)
# Requirement already satisfied: ipywidgets>=8.0.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (8.1.2)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (14.0.2)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (3.0.1)
# Requirement already satisfied: scikit_learn<1.8.0,>=1.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (1.2.2)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (4.65.0)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (13.3.5)
# Requirement already satisfied: regex>=2023.8.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (2023.10.3)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (2.1.4)
# Requirement already satisfied: pyjwt>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (2.4.0)
# Requirement already satisfied: pyspark>=3.4.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (3.5.1.5.4.20240407)
# Requirement already satisfied: requests>=2.31.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (2.31.0)
# Requirement already satisfied: aiohttp>=3.8.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (3.9.3)
# Requirement already satisfied: IPython>=8.14.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (8.20.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.14.1->semantic-link) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.14.1->semantic-link) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.14.1->semantic-link) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.14.1->semantic-link) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.14.1->semantic-link) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy==0.14.1->semantic-link) (1.9.3)
# Requirement already satisfied: isodate>=0.6.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-keyvault-secrets>=4.7.0->semantic-link-sempy==0.14.1->semantic-link) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-keyvault-secrets>=4.7.0->semantic-link-sempy==0.14.1->semantic-link) (4.9.0)
# Requirement already satisfied: cryptography>=2.1.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-storage-blob>=12.18.3->semantic-link-sempy==0.14.1->semantic-link) (42.0.2)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from clr_loader>=0.2.5->semantic-link-sempy==0.14.1->semantic-link) (1.16.0)
# Requirement already satisfied: psutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy==0.14.1->semantic-link) (5.9.0)
# Requirement already satisfied: azure-identity in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy==0.14.1->semantic-link) (1.15.0)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.14.1->semantic-link) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.14.1->semantic-link) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.14.1->semantic-link) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.14.1->semantic-link) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.14.1->semantic-link) (2.15.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.14.1->semantic-link) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.14.1->semantic-link) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy==0.14.1->semantic-link) (4.8.0)
# Requirement already satisfied: comm>=0.1.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=8.0.7->semantic-link-sempy==0.14.1->semantic-link) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=8.0.7->semantic-link-sempy==0.14.1->semantic-link) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=8.0.7->semantic-link-sempy==0.14.1->semantic-link) (3.0.10)
# Requirement already satisfied: numpy<2,>=1.23.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy==0.14.1->semantic-link) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy==0.14.1->semantic-link) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy==0.14.1->semantic-link) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy==0.14.1->semantic-link) (2023.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyspark>=3.4.1->semantic-link-sempy==0.14.1->semantic-link) (0.10.9.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy==0.14.1->semantic-link) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy==0.14.1->semantic-link) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy==0.14.1->semantic-link) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy==0.14.1->semantic-link) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy==0.14.1->semantic-link) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit_learn<1.8.0,>=1.2.2->semantic-link-sempy==0.14.1->semantic-link) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit_learn<1.8.0,>=1.2.2->semantic-link-sempy==0.14.1->semantic-link) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit_learn<1.8.0,>=1.2.2->semantic-link-sempy==0.14.1->semantic-link) (2.2.0)
# Collecting branca>=0.6.0 (from folium->semantic-link-functions-geopandas==0.14.1->semantic-link)
#   Downloading branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: jinja2>=2.9 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from folium->semantic-link-functions-geopandas==0.14.1->semantic-link) (3.1.3)
# Requirement already satisfied: xyzservices in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from folium->semantic-link-functions-geopandas==0.14.1->semantic-link) (2022.9.0)
# Collecting pyogrio>=0.7.2 (from geopandas->semantic-link-functions-geopandas==0.14.1->semantic-link)
#   Downloading pyogrio-0.12.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Requirement already satisfied: packaging in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from geopandas->semantic-link-functions-geopandas==0.14.1->semantic-link) (23.1)
# Collecting pyproj>=3.5.0 (from geopandas->semantic-link-functions-geopandas==0.14.1->semantic-link)
#   Downloading pyproj-3.7.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas->semantic-link-functions-geopandas==0.14.1->semantic-link)
#   Downloading shapely-2.1.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.8 kB)
# Collecting networkx>=3.2 (from mapclassify->semantic-link-functions-geopandas==0.14.1->semantic-link)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting scikit_learn<1.8.0,>=1.2.2 (from semantic-link-sempy==0.14.1->semantic-link)
#   Downloading scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting scipy>=1.3.2 (from scikit_learn<1.8.0,>=1.2.2->semantic-link-sempy==0.14.1->semantic-link)
#   Downloading scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 20.2 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0 (from scikit_learn<1.8.0,>=1.2.2->semantic-link-sempy==0.14.1->semantic-link)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting pandas<3.0.0,>=1.5.3 (from semantic-link-sempy==0.14.1->semantic-link)
#   Downloading pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 29.2 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.13->clr_loader>=0.2.5->semantic-link-sempy==0.14.1->semantic-link) (2.21)
# Requirement already satisfied: six in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from isodate>=0.6.1->azure-keyvault-secrets>=4.7.0->semantic-link-sempy==0.14.1->semantic-link) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jedi>=0.16->IPython>=8.14.0->semantic-link-sempy==0.14.1->semantic-link) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jinja2>=2.9->folium->semantic-link-functions-geopandas==0.14.1->semantic-link) (2.1.3)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=13.3.5->semantic-link-sempy==0.14.1->semantic-link) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pexpect>4.3->IPython>=8.14.0->semantic-link-sempy==0.14.1->semantic-link) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.14.0->semantic-link-sempy==0.14.1->semantic-link) (0.2.5)
# Collecting azure-core>=1.29.4 (from semantic-link-sempy==0.14.1->semantic-link)
#   Downloading azure_core-1.40.0-py3-none-any.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: msal<2.0.0,>=1.24.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy==0.14.1->semantic-link) (1.25.0)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy==0.14.1->semantic-link) (1.0.0)
# Requirement already satisfied: executing in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy==0.14.1->semantic-link) (0.8.3)
# Requirement already satisfied: asttokens in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy==0.14.1->semantic-link) (2.0.5)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy==0.14.1->semantic-link) (0.2.2)
# Requirement already satisfied: portalocker<3,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy==0.14.1->semantic-link) (2.3.0)
# Downloading semantic_link-0.14.1-py3-none-any.whl (13 kB)
# Downloading semantic_link_functions_geopandas-0.14.1-py3-none-any.whl (4.1 kB)
# Downloading semantic_link_functions_holidays-0.14.1-py3-none-any.whl (4.3 kB)
# Downloading semantic_link_functions_meteostat-0.14.1-py3-none-any.whl (4.6 kB)
# Downloading semantic_link_functions_phonenumbers-0.14.1-py3-none-any.whl (4.4 kB)
# Downloading semantic_link_functions_validators-0.14.1-py3-none-any.whl (4.9 kB)
# Downloading semantic_link_sempy-0.14.1-py3-none-any.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 125.1 MB/s eta 0:00:00
# Downloading azure_keyvault_secrets-4.11.0-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 31.9 MB/s eta 0:00:00
# Downloading fabric_analytics_notebook_plugin-0.0.3.post4-py3-none-any.whl (24 kB)
# Downloading fabric_analytics_sdk-0.0.3.post1-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 14.1 MB/s eta 0:00:00
# Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.4/113.4 kB 35.7 MB/s eta 0:00:00
# Downloading geopandas-1.1.3-py3-none-any.whl (342 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.5/342.5 kB 68.3 MB/s eta 0:00:00
# Downloading mapclassify-2.10.0-py3-none-any.whl (882 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 102.4 MB/s eta 0:00:00
# Downloading scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 133.9 MB/s eta 0:00:0000:0100:01
# Downloading meteostat-2.1.4-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.8/93.8 kB 31.7 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 139.2 MB/s eta 0:00:0000:010:01
# Downloading phonenumbers-9.0.29-py2.py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 139.9 MB/s eta 0:00:00
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 14.7 MB/s eta 0:00:00
# Downloading branca-0.8.2-py3-none-any.whl (26 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 118.2 MB/s eta 0:00:00
# Downloading pyogrio-0.12.1-cp311-cp311-manylinux_2_28_x86_64.whl (32.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.5/32.5 MB 104.3 MB/s eta 0:00:0000:0100:01
# Downloading pyproj-3.7.2-cp311-cp311-manylinux_2_28_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 144.8 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 99.0 MB/s eta 0:00:00:00:0100:01
# Downloading shapely-2.1.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 148.4 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading azure_core-1.40.0-py3-none-any.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.4/220.4 kB 57.1 MB/s eta 0:00:00
# Installing collected packages: validators, threadpoolctl, shapely, scipy, pyproj, pyogrio, phonenumbers, networkx, scikit_learn, pandas, branca, azure-core, meteostat, mapclassify, geopandas, folium, azure-keyvault-secrets, fabric-analytics-sdk, fabric-analytics-notebook-plugin, semantic-link-sempy, semantic-link-functions-validators, semantic-link-functions-phonenumbers, semantic-link-functions-meteostat, semantic-link-functions-holidays, semantic-link-functions-geopandas, semantic-link
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.2.0
#     Not uninstalling threadpoolctl at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16
#     Can't uninstall 'threadpoolctl'. No files were found to uninstall.
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Not uninstalling scipy at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16
#     Can't uninstall 'scipy'. No files were found to uninstall.
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Not uninstalling networkx at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16
#     Can't uninstall 'networkx'. No files were found to uninstall.
#   Attempting uninstall: scikit_learn
#     Found existing installation: scikit-learn 1.2.2
#     Not uninstalling scikit-learn at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16
#     Can't uninstall 'scikit-learn'. No files were found to uninstall.
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Not uninstalling pandas at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16
#     Can't uninstall 'pandas'. No files were found to uninstall.
#   Attempting uninstall: azure-core
#     Found existing installation: azure-core 2024.9.1
#     Not uninstalling azure-core at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16
#     Can't uninstall 'azure-core'. No files were found to uninstall.
#   Attempting uninstall: semantic-link-sempy
#     Found existing installation: semantic-link-sempy 0.11.0
#     Not uninstalling semantic-link-sempy at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16
#     Can't uninstall 'semantic-link-sempy'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nni 3.0 requires filelock<3.12, but you have filelock 3.13.1 which is incompatible.
# datasets 2.19.1 requires fsspec[http]<=2024.3.1,>=2023.1.0, but you have fsspec 2024.6.1 which is incompatible.
# fsspec-wrapper 0.1.15 requires PyJWT>=2.6.0, but you have pyjwt 2.4.0 which is incompatible.
# Successfully installed azure-core-1.40.0 azure-keyvault-secrets-4.11.0 branca-0.8.2 fabric-analytics-notebook-plugin-0.0.3.post4 fabric-analytics-sdk-0.0.3.post1 folium-0.20.0 geopandas-1.1.3 mapclassify-2.10.0 meteostat-2.1.4 networkx-3.6.1 pandas-2.3.3 phonenumbers-9.0.29 pyogrio-0.12.1 pyproj-3.7.2 scikit_learn-1.7.2 scipy-1.17.1 semantic-link-0.14.1 semantic-link-functions-geopandas-0.14.1 semantic-link-functions-holidays-0.14.1 semantic-link-functions-meteostat-0.14.1 semantic-link-functions-phonenumbers-0.14.1 semantic-link-functions-validators-0.14.1 semantic-link-sempy-0.14.1 shapely-2.1.2 threadpoolctl-3.6.0 validators-0.35.0
#
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting semantic-link-labs
#   Downloading semantic_link_labs-0.14.3-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: semantic-link-sempy>=0.14.0 in /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages (from semantic-link-labs) (0.14.1)
# Collecting anytree (from semantic-link-labs)
#   Downloading anytree-2.13.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting polib (from semantic-link-labs)
#   Downloading polib-1.2.0-py2.py3-none-any.whl.metadata (15 kB)
# Collecting jsonpath_ng (from semantic-link-labs)
#   Downloading jsonpath_ng-1.8.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: clr_loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (0.2.5)
# Requirement already satisfied: fabric-analytics-sdk<1.0.0,>=0.0.3 in /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (0.0.3.post1)
# Requirement already satisfied: fabric-analytics-notebook-plugin<1.0.0,>=0.0.3 in /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (0.0.3.post4)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (0.20.1)
# Requirement already satisfied: azure-storage-blob>=12.18.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (12.22.0)
# Requirement already satisfied: azure-core>=1.29.4 in /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (1.40.0)
# Requirement already satisfied: azure-keyvault-secrets>=4.7.0 in /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (4.11.0)
# Requirement already satisfied: azure-storage-file-datalake>=12.12.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (12.16.0)
# Requirement already satisfied: ipywidgets>=8.0.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (8.1.2)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (14.0.2)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (3.0.1)
# Requirement already satisfied: scikit_learn<1.8.0,>=1.2.2 in /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (1.7.2)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (4.65.0)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (13.3.5)
# Requirement already satisfied: regex>=2023.8.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (2023.10.3)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (2.3.3)
# Requirement already satisfied: pyjwt>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (2.4.0)
# Requirement already satisfied: pyspark>=3.4.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (3.5.1.5.4.20240407)
# Requirement already satisfied: requests>=2.31.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (2.31.0)
# Requirement already satisfied: aiohttp>=3.8.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (3.9.3)
# Requirement already satisfied: IPython>=8.14.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (8.20.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.0->semantic-link-labs) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.0->semantic-link-labs) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.9.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-core>=1.29.4->semantic-link-sempy>=0.14.0->semantic-link-labs) (4.9.0)
# Requirement already satisfied: isodate>=0.6.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-keyvault-secrets>=4.7.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.6.1)
# Requirement already satisfied: cryptography>=2.1.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-storage-blob>=12.18.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (42.0.2)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from clr_loader>=0.2.5->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.16.0)
# Requirement already satisfied: psutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (5.9.0)
# Requirement already satisfied: azure-identity in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.15.0)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.15.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (4.8.0)
# Requirement already satisfied: comm>=0.1.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=8.0.7->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=8.0.7->semantic-link-sempy>=0.14.0->semantic-link-labs) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=8.0.7->semantic-link-sempy>=0.14.0->semantic-link-labs) (3.0.10)
# Requirement already satisfied: numpy>=1.23.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (2023.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyspark>=3.4.1->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.10.9.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.2.0)
# Requirement already satisfied: scipy>=1.8.0 in /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages (from scikit_learn<1.8.0,>=1.2.2->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.17.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit_learn<1.8.0,>=1.2.2->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages (from scikit_learn<1.8.0,>=1.2.2->semantic-link-sempy>=0.14.0->semantic-link-labs) (3.6.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.13->clr_loader>=0.2.5->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.21)
# Requirement already satisfied: six in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from isodate>=0.6.1->azure-keyvault-secrets>=4.7.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jedi>=0.16->IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=13.3.5->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pexpect>4.3->IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.2.5)
# Requirement already satisfied: msal<2.0.0,>=1.24.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.25.0)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.0.0)
# Requirement already satisfied: executing in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.8.3)
# Requirement already satisfied: asttokens in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.0.5)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.2.2)
# Requirement already satisfied: portalocker<3,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.3.0)
# Downloading semantic_link_labs-0.14.3-py3-none-any.whl (888 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 888.0/888.0 kB 49.8 MB/s eta 0:00:00
# Downloading anytree-2.13.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 15.6 MB/s eta 0:00:00
# Downloading jsonpath_ng-1.8.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 24.8 MB/s eta 0:00:00
# Downloading polib-1.2.0-py2.py3-none-any.whl (20 kB)
# Installing collected packages: polib, jsonpath_ng, anytree, semantic-link-labs
# Successfully installed anytree-2.13.0 jsonpath_ng-1.8.0 polib-1.2.0 semantic-link-labs-0.14.3
#
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %%
#import necessary libraries
import sempy.fabric as fabric
import pandas as pd
import numpy as np
import re
from notebookutils import mssparkutils

import sempy_labs as labs
from sempy_labs import directlake
from sempy_labs.tom import connect_semantic_model


# set temporary config for date issue
spark.conf.set("spark.sql.parquet.datetimeRebaseModeInWrite", "CORRECTED")
spark.conf.set("spark.sql.parquet.datetimeRebaseModeInRead", "CORRECTED")

##########################################################################################################
##                    THIS IS THE SECTION THAT REQUIRES INITIAL CONFIGURATION BY THE USER
##########################################################################################################
########################################################################################
###   MANUAL CONFIG HERE
#######################################################################################
#Define lakehouse and schema names
workspace_name = "amaser_dp700" #this is the workspace name where the notebook runs, and where the lakehouse lives
lakehouse_name = "lh_FabricManagement" #this is the name of the lakehouse, in the event that it needs to becreated by this notebook
lakehouse_description = "Fabric Management lakehouse"  # this is only used if the notebook creates a new lakehouse
semantic_model_name = "sem_ModelCatalog" ###NOTE: IF THIS MODEL ALREADY EXISTS, IT WILL BE OVERWRITTEN
schema_name = "modelcatalog" # NOTE, if you're using an existing non-schema-enabled lakehouse, this MUST be set to 'dbo'
model_type = "DirectLake"  # enter DirectLake if a DirectLake semantic model is desired.  Otherwise, enter Import

# Define colors for table navigator page.  You don't need to adjust these, unless you want to rebrand the report
factcolor = '#A6B916'
dimcolor = '#C8B78A'
defaultcolor = '#A66999'

#Create list of workspaces and Models.  This allows users to limit which models get documented.  A user could also
#   tweak this notebook, to use sempy functions, and query all workspaces/models that he/she has access to, if that's preferred.
#THE ORDER OF THE WORKSPACES AND MODELS MUST BE THE SAME
#  ie the third report MUST be in the third workspace
data = {
    'Workspace': ['Industry Demos','amaser_dp700','Industry Demos','amaser_dp700'
    ],
    'Model': ['Insurance Power BI Demo','FabricInventory','Product Model','devopsdemo'
    ]
}
###########################################################################################
## from this section onward, there shouldn't be any updating necessary
#######################################################################################################

workspace_id = fabric.get_workspace_id()

#######################################################
## Check for existing items
######################################################
## check if lakehouse exists.  If not, create a lakehouse (non schema-enabled)
try:
    lakehouse_object = mssparkutils.lakehouse.get(lakehouse_name)
    lakehouse_id=lakehouse_object.id
except Exception as e:
    try:
        fabric.create_lakehouse(display_name=lakehouse_name,description=lakehouse_description,workspace=workspace_name,enable_schema=True)
        lakehouse_object = mssparkutils.lakehouse.get(lakehouse_name)
        lakehouse_id=lakehouse_object.id
    except Exception as e:
        print('Unable to create lakehouse')
        print(e)


lakehouse_value = f'{workspace_name}.{lakehouse_name}.'
lakehouse_value_full = f'{workspace_name}.{lakehouse_name}.{schema_name}.'
#Create schema if not exists
schema_sql = f"CREATE SCHEMA IF NOT EXISTS {workspace_name}.{lakehouse_name}.{schema_name}"
spark.sql(schema_sql)
print("Schema exists, or was created")
#print(lakehouse_value)

####################################################################################################################


#DEFINE FUNCTIONS


#function to write the dataframe as a database
def writeTable(pd_df, tablename):
  if len(pd_df) != 0:
    query = f"drop table if exists {lakehouse_value_full}{tablename}"
    spark.sql(query)
    spark_df = spark.createDataFrame(pd_df)
    full_table_name = f'{lakehouse_value_full}{tablename}'
    #print(full_table_name)
    try:
        spark_df.write.format("delta").mode("overwrite").option("overwriteSchema","true").saveAsTable(full_table_name)
        print(f'{tablename} written to lakehouse')
    except Exception as e:
        print(f'Failed to write {tablename}')
  else:
    # if no data (ie no hierarchies exist) create a table so tahat the relationship code will work, and refreshes won't fail
    #   The page related to these will need to be hidden, in the event that one of the tables isnt used in any of your models
    strcreatequery = f'Create TABLE IF NOT EXISTS {lakehouse_value_full}{tablename} (semanticmodel_id INTEGER, {tablename}_name STRING)'
    spark.sql(strcreatequery)       

#function to get data from model
def getMetaData(daxquery,fieldname,indexfield):
    indexname = indexfield+'_id'
    #build out first row
    model_df = fabric.evaluate_dax(
        workspace=df.iloc[0,0],
        dataset=df.iloc[0,1],
        dax_string=daxquery
    )
    model_df['semanticmodel_id'] = df.iloc[0,3]
    model_df['SemanticModel'] = df.iloc[0,1]
    #cycle through remaining rows, if more than 1 row
    if len(df) > 1:
        for index,row in df.iloc[1:].iterrows():
            temp_df = fabric.evaluate_dax(
                workspace=df.iloc[index,0],
                dataset=df.iloc[index,1],
                dax_string=dax_query
            )
            temp_df['semanticmodel_id']=df.iloc[index,3]
            temp_df['SemanticModel'] = df.iloc[index,1]
            #print('temp df executed')
            #append most recent
            model_df = pd.concat([model_df,temp_df],ignore_index=True)

    model_df.columns = model_df.columns.str.replace('[', '')
    model_df.columns = model_df.columns.str.replace(']', '')
    model_df = model_df.rename(columns={'Name':fieldname})
    model_df[indexname] = model_df.index + 1
    return model_df


# Function to extract hashtags from a string
def extract_hashtags(description):
    if isinstance(description, str):  # Check if description is a string
        hashtags = re.findall(r'%%(\w+)', description)
        return hashtags
    else:
        return []
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 11, Finished, Available, Finished, False)
# Schema exists, or was created

# %% [markdown]
# Process list of semantic models from the user-defined list. save as a table in the lakehouse

# %%
# take the provided workspaces/models and convert it to a dataframe.  Add the full path as an extra column.
df = pd.DataFrame(data)
df['WorkspacePath'] = f'powerbi://api.powerbi.com/v1.0/myorg/'+ df['Workspace']
df['semanticmodel_id'] = df.index + 1 # addsan auto increment index to  the table.


writeTable(df,"SemanticModel")
print('SemanticModel processing completed')
#print(df)
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 12, Finished, Available, Finished, False)
# SemanticModel written to lakehouse
# SemanticModel processing completed

# %% [markdown]
# Process Model query.  Save Model data to the lakehouse

# %%
#Get Model Data
print('Model processing started')
dax_query = "EVALUATE INFO.MODEL()"
model_df = getMetaData(dax_query,'ModelName','model')
#display(model_df)

writeTable(model_df,"Model")
print('Model processing completed')
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 13, Finished, Available, Finished, False)
# Model processing started
# Model written to lakehouse
# Model processing completed

# %% [markdown]
# Process Tables dax query to collect table data from all defined models

# %%
#get Table Data
print('Table processing started')
dax_query = """EVALUATE
VAR __tables =
    INFO.TABLES ()
VAR __storagemode =
    SELECTCOLUMNS ( INFO.VIEW.TABLES (), \"ID\", [ID], \"StorageMode\", [StorageMode] )
VAR __combined =
    NATURALLEFTOUTERJOIN ( __tables, __storagemode )
RETURN
    __combined

"""
table_df = getMetaData(dax_query,'TableName','table')

#add table type column for slicer. Cleanup column names and create combined key for joining
table_df['TableType']=table_df['Description'].apply(lambda x:extract_hashtags(x))
table_df['TableType']=table_df['TableType'].astype(str)
table_df['TableType'] = table_df['TableType'].str.removeprefix('[\'')
table_df['TableType'] = table_df['TableType'].str.replace('\']', '')
table_df['TableType'] = table_df['TableType'].str.replace(']', '')
table_df['TableType'] = table_df['TableType'].str.replace('[', '')
table_df['compoundkey'] = table_df['SemanticModel'] + table_df['ID'].astype(str)

#display(table_df)
writeTable(table_df,"PBITables")
print('Table processing completed')
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 14, Finished, Available, Finished, False)
# Table processing started
# PBITables written to lakehouse
# Table processing completed

# %% [markdown]
# collect measure data from listed models and store in the lakehouse

# %%
#get measure Data
print('MeasureList processing started')
dax_query = "EVALUATE INFO.Measures()"
measure_df = getMetaData(dax_query,'MeasureName','measures')
measure_df['compoundkey'] = measure_df['semanticmodel_id'].astype(str) + measure_df['MeasureName']
#display(measure_df)

writeTable(measure_df,"MeasureList")
print('MeasureList processing completed')
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 15, Finished, Available, Finished, False)
# MeasureList processing started
# /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages/sempy/_metadata/_mdataframe.py:289: UserWarning: Conflicting metadata for column '[State]'. Choosing first encountered
#   warnings.warn(f"Conflicting metadata for column '{name}'. Choosing first encountered")
# SynapseWidget(Synapse.DataFrame, 645e3cff-21f6-4798-bb97-303528809ec7)
# MeasureList written to lakehouse
# MeasureList processing completed

# %% [markdown]
# get role data (if any) from all selected models, and store it in the lakehouse

# %%
#get role Data
print('Role processing started')
dax_query = "EVALUATE INFO.Roles()"
role_df = getMetaData(dax_query,'RoleName','roles')

#display(role_df)

writeTable(role_df,"PBIRoles")
print('Role processing completed')
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 16, Finished, Available, Finished, False)
# Role processing started
# PBIRoles written to lakehouse
# Role processing completed

# %% [markdown]
# get data about any partitions.  This may only be important in regards to incremental refresh, but either way, the data is available in the documentation lakehouse

# %%
#get partition Data
print('Partition processing started')
dax_query = """
EVALUATE
VAR __partitions =
    INFO.PARTITIONS ()
VAR __refreshpolicies =
    SELECTCOLUMNS (
        INFO.REFRESHPOLICIES (),
        \"TableID\", [TableID],
        \"SourceExpression\", [SourceExpression]
    )
VAR __combined =
    NATURALLEFTOUTERJOIN ( __partitions, __refreshpolicies )
RETURN
    __combined
"""
partition_df = getMetaData(dax_query,'PartitionName','partitions')

#add extra columns for joins, and cleanup unused columns
partition_df['compoundkey'] = partition_df['SemanticModel'] + partition_df['TableID'].astype(str)
partition_df =pd.merge(partition_df,table_df[['compoundkey','TableName']],left_on='compoundkey',right_on='compoundkey',how='left')
partition_df['Source'] = np.where(partition_df['QueryDefinition'].isnull(),partition_df['SourceExpression'],partition_df['QueryDefinition'])
partition_df = partition_df.drop(['QueryDefinition','SourceExpression'],axis=1)
#display(partition_df)

writeTable(partition_df,"Partitions")
print('Partition processing completed')
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 17, Finished, Available, Finished, False)
# Partition processing started
# Partitions written to lakehouse
# Partition processing completed
# /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages/sempy/_metadata/_mdataframe.py:289: UserWarning: Conflicting metadata for column '[State]'. Choosing first encountered
#   warnings.warn(f"Conflicting metadata for column '{name}'. Choosing first encountered")

# %% [markdown]
# get expression data.  This includes data sources (as shown in TE) and any parameters that may be defined.

# %%
#get expression Data
print('Expression processing started')
dax_query = "EVALUATE INFO.Expressions()"
expression_df = getMetaData(dax_query,'ExpressionName','expression')

#display(expression_df)

writeTable(expression_df,"Expression")
print('Expression processing completed')
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 18, Finished, Available, Finished, False)
# Expression processing started
# Expression written to lakehouse
# Expression processing completed

# %%
#get dependency Data
print('Dependency processing started')
dax_query  = "EVALUATE INFO.DEPENDENCIES()"
dependency_df = getMetaData(dax_query,"DependencyName",'dependency')
dependency_df['compoundkey'] = dependency_df['semanticmodel_id'].astype(str) + dependency_df['OBJECT']
dependency_df = dependency_df.query("OBJECT_TYPE == 'MEASURE'")
#ser_workspaces_df.query("type != 'Personal' & state == 'Active'")
#display(dependency_df)

writeTable(dependency_df,"dependencies")
print('Dependency processing completed')
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 19, Finished, Available, Finished, False)
# Dependency processing started
# dependencies written to lakehouse
# Dependency processing completed

# %% [markdown]
# get hierarchy data (if any)

# %%
#get hierarchy Data
print('Hierarchy processing started')
dax_query = "EVALUATE INFO.Hierarchies()"
hierarchy_df = getMetaData(dax_query,'HierarchyName','hierarchy')

#display(final_df)
#add colulmn for join with table
hierarchy_df['compoundkey'] = hierarchy_df['SemanticModel'] + hierarchy_df['TableID'].astype(str)

hierarchy_df =pd.merge(hierarchy_df,table_df[['compoundkey','TableName']],left_on='compoundkey',right_on='compoundkey',how='left')
#display(hierarchy_df)

writeTable(hierarchy_df,"Hierarchies")
print('Hierarchy processing completed')
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 20, Finished, Available, Finished, False)
# Hierarchy processing started
# Hierarchies written to lakehouse
# Hierarchy processing completed
# /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages/sempy/_metadata/_mdataframe.py:289: UserWarning: Conflicting metadata for column '[State]'. Choosing first encountered
#   warnings.warn(f"Conflicting metadata for column '{name}'. Choosing first encountered")

# %% [markdown]
# get column data from selected models

# %%
#get column Data
print('Column processing started')
dax_query = "EVALUATE INFO.Columns()"
columns_df = getMetaData(dax_query,'ColumnName','column')

#add compound key for table join.  add colulmn to determine calculated columns (used for slicer)
columns_df['compoundkey'] = columns_df['SemanticModel'] + columns_df['TableID'].astype(str)
columns_df =pd.merge(columns_df,table_df[['compoundkey','TableName']],left_on='compoundkey',right_on='compoundkey',how='left')
columns_df['ColumnName'] = columns_df['ExplicitName'].combine_first(columns_df['InferredName'])
del columns_df['ExplicitName']
del columns_df['InferredName']
columns_df['ColumnType'] = np.where(columns_df['Expression'].isnull(),'Standard','Calculated')
#display(columns_df)

writeTable(columns_df,"PBIColumns")
print('Column processing completed')
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 21, Finished, Available, Finished, False)
# Column processing started
# PBIColumns written to lakehouse
# Column processing completed
# /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages/sempy/_metadata/_mdataframe.py:289: UserWarning: Conflicting metadata for column '[State]'. Choosing first encountered
#   warnings.warn(f"Conflicting metadata for column '{name}'. Choosing first encountered")

# %% [markdown]
# get info on any calculation groups from selected models

# %%
#get calculation groups
print('Calculation Item processing started')
dax_query = "EVALUATE INFO.CalculationGroups()"
calcgroup_df = getMetaData(dax_query,'CalculationGroupName','calcgroup')
calcgroup_df['compoundkey'] = calcgroup_df['SemanticModel'] + calcgroup_df['TableID'].astype(str)
calcgroup_df['groupcompoundkey'] = calcgroup_df['SemanticModel'] + calcgroup_df['ID'].astype(str)
calcgroup_df =pd.merge(calcgroup_df,table_df[['compoundkey','TableName']],left_on='compoundkey',right_on='compoundkey',how='left')
calcgroup_df['CalculationGroupName'] = calcgroup_df['TableName']
#display(calcgroup_df)

#get calcitems
dax_query = "EVALUATE INFO.CalculationItems()"
items_df = getMetaData(dax_query,'CalculationItemName','calcitem')
items_df['compoundkey'] = items_df['SemanticModel'] + items_df['CalculationGroupID'].astype(str)
items_df = pd.merge(items_df,calcgroup_df[['groupcompoundkey','CalculationGroupName','Precedence']],left_on='compoundkey',right_on='groupcompoundkey',how='left')
items_df = items_df.rename(columns={'Precedence':'GroupPrecedence'})
#display(items_df)

writeTable(items_df,"CalculationItems")
print('Calculation Item processing completed')
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 22, Finished, Available, Finished, False)
# Calculation Item processing started
# CalculationItems written to lakehouse
# Calculation Item processing completed
# /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages/sempy/_metadata/_mdataframe.py:289: UserWarning: Conflicting metadata for column '[State]'. Choosing first encountered
#   warnings.warn(f"Conflicting metadata for column '{name}'. Choosing first encountered")

# %% [markdown]
# get Relationship data from selected models.  this does not include relationships for this documentation model

# %%
#get relationships
print('Relationship processing started')
dax_query = "EVALUATE INFO.Relationships()"
relationship_df = getMetaData(dax_query,'RelationshipName','relationship')
# clean up colulmns for to/from relationships.  
relationship_df['FromCompoundKey'] = relationship_df['SemanticModel'] + relationship_df['FromTableID'].astype(str)
relationship_df['ToCompoundKey'] = relationship_df['SemanticModel'] + relationship_df['ToTableID'].astype(str)
relationship_df =pd.merge(relationship_df,table_df[['compoundkey','TableName','TableType']],left_on='FromCompoundKey',right_on='compoundkey',how='left')
relationship_df = relationship_df.rename(columns={'TableName':'FromTableName','TableType':'FromTableType'})
relationship_df =pd.merge(relationship_df,table_df[['compoundkey','TableName','TableType']],left_on='ToCompoundKey',right_on='compoundkey',how='left')
relationship_df = relationship_df.rename(columns={'TableName':'ToTableName','TableType':'ToTableType'})
relationship_df['FromCardinality'] = relationship_df['FromCardinality'].astype(str)
relationship_df['FromCardinality'] = relationship_df['FromCardinality'].replace('2','Many')
relationship_df['ToCardinality'] = relationship_df['ToCardinality'].astype(str)
relationship_df['ToCardinality'] = relationship_df['ToCardinality'].replace('2','Many')
####################################################################################################################
#define parameters. you do not need to edit this section
FromCondition = [
    (relationship_df['FromTableType'] == 'Fact'),
    (relationship_df['FromTableType'] == 'Dimension')
]
ToCondition = [
    (relationship_df['ToTableType'] == 'Fact'),
    (relationship_df['ToTableType'] == 'Dimension')
]
values = [factcolor,dimcolor]
###########################################################################################
relationship_df['ToColor'] = np.select(ToCondition,values,default=defaultcolor)
relationship_df['FromColor'] = np.select(FromCondition,values,default=defaultcolor)
#display(relationship_df)

writeTable(relationship_df,"Relationships")
print('Relationship processing completed')
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 23, Finished, Available, Finished, False)
# Relationship processing started
# Relationships written to lakehouse
# Relationship processing completed
# /nfs4/pyenv-37a6bfb2-7678-4006-9e6a-9b5a2fd7ae16/lib/python3.11/site-packages/sempy/_metadata/_mdataframe.py:289: UserWarning: Conflicting metadata for column '[State]'. Choosing first encountered
#   warnings.warn(f"Conflicting metadata for column '{name}'. Choosing first encountered")

# %%
if model_type == "DirectLake":
    ##Check if semantic model exists
    
    # List all datasets in the workspace
    # If workspace_name is not provided, it defaults to the notebook's attached lakehouse workspace or the notebook's own workspace.
    all_datasets = fabric.list_datasets(workspace=workspace_name if workspace_name in locals() else None)

    # Check if the semantic model exists in the list
    if semantic_model_name in all_datasets['Dataset Name'].values:
        print(f"The semantic model '{semantic_model_name}' exists in the workspace.")
        print("THE SEMANTIC MODEL WILL BE REPLACED")
        
    else:
        print(f"The semantic model '{semantic_model_name}' does not exist in the workspace.")
        

    table_list = ["calculationitems","dependencies","expression","hierarchies","measurelist","model","partitions","pbicolumns","pbiroles","pbitables","relationships","semanticmodel"]

    directlake.generate_direct_lake_semantic_model(dataset=semantic_model_name,lakehouse_tables=table_list,workspace=workspace_name,lakehouse=lakehouse_name,lakehouse_workspace=workspace_name,schema=schema_name,overwrite=True,refresh=True) 
    df_datasets = fabric.list_datasets()
    semantic_model_id = df_datasets[df_datasets['Dataset Name'] == semantic_model_name]['Dataset ID'].iloc[0]
    print(f"Created Semantic Model {semantic_model_name}")
    ##rename tables
    with fabric.connect_semantic_model(dataset=semantic_model_name, workspace=workspace_name, readonly=False) as tom:
        # Iterate through all tables in the model to find the target table
        for table in tom.model.Tables:
            #print(table.Name)
            if table.Name == 'expression':
                table.Name = 'Expressions'
            if table.Name == 'calculationitems':
                table.Name = 'Calculation Items'
            if table.Name == 'hierarchies':
                table.Name = 'Hierarchies'
            if table.Name == 'measurelist':
                table.Name = 'Measure List'
            if table.Name == 'model':
                table.Name = 'Models'
            if table.Name == 'partitions':
                table.Name = 'Partitions'
            if table.Name == 'pbicolumns':
                table.Name = 'Columns'
            if table.Name == 'pbiroles':
                table.Name = 'Roles'
            if table.Name == 'pbitables':
                table.Name = 'Tables'
            if table.Name == 'relationships':
                table.Name = 'Relationships'
            if table.Name == 'semanticmodel':
                table.Name = 'Semantic Models'
            if table.Name == 'dependencies':
                table.Name = 'Dependencies'
    
        print("Table rename completed")
        

       
    #create relationships for directlake model
    with labs.tom.connect_semantic_model(dataset=semantic_model_name,
                            workspace=workspace_name,
                            readonly=False) as model:    
        
        model.add_relationship(
            to_table="Semantic Models",
            to_column="semanticmodel_id",
            from_table="Models",
            from_column="semanticmodel_id",
            from_cardinality="Many",
            to_cardinality="One",
            cross_filtering_behavior="Automatic",
            is_active=True
        )
        model.add_relationship(
            to_table="Semantic Models",
            to_column="semanticmodel_id",
            from_table="Tables",
            from_column="semanticmodel_id",
            from_cardinality="Many",
            to_cardinality="One",
            cross_filtering_behavior="Automatic",
            is_active=True
        )
        model.add_relationship(
            to_table="Tables",
            to_column="compoundkey",
            from_table="Columns",
            from_column="compoundkey",
            from_cardinality="Many",
            to_cardinality="One",
            cross_filtering_behavior="Automatic",
            is_active=True
        )
        model.add_relationship(
            to_table="Semantic Models",
            to_column="semanticmodel_id",
            from_table="Calculation Items",
            from_column="semanticmodel_id",
            from_cardinality="Many",
            to_cardinality="One",
            cross_filtering_behavior="Automatic",
            is_active=True
        )
        model.add_relationship(
            to_table="Semantic Models",
            to_column="semanticmodel_id",
            from_table="Expressions",
            from_column="semanticmodel_id",
            from_cardinality="Many",
            to_cardinality="One",
            cross_filtering_behavior="Automatic",
            is_active=True
        )
        model.add_relationship(
            to_table="Semantic Models",
            to_column="semanticmodel_id",
            from_table="Measure List",
            from_column="semanticmodel_id",
            from_cardinality="Many",
            to_cardinality="One",
            cross_filtering_behavior="Automatic",
            is_active=True
        )
        model.add_relationship(
            to_table="Semantic Models",
            to_column="semanticmodel_id",
            from_table="Hierarchies",
            from_column="semanticmodel_id",
            from_cardinality="Many",
            to_cardinality="One",
            cross_filtering_behavior="Automatic",
            is_active=True
        )
        model.add_relationship(
            to_table="Semantic Models",
            to_column="semanticmodel_id",
            from_table="Partitions",
            from_column="semanticmodel_id",
            from_cardinality="Many",
            to_cardinality="One",
            cross_filtering_behavior="Automatic",
            is_active=True
        )
        model.add_relationship(
            to_table="Semantic Models",
            to_column="semanticmodel_id",
            from_table="Roles",
            from_column="semanticmodel_id",
            from_cardinality="Many",
            to_cardinality="One",
            cross_filtering_behavior="Automatic",
            is_active=True
        )
        model.add_relationship(
            to_table="Measure List",
            to_column="compoundkey",
            from_table="Dependencies",
            from_column="compoundkey",
            from_cardinality="Many",
            to_cardinality="One",
            cross_filtering_behavior="Automatic",
            is_active=True
        )
        model.add_relationship(
            to_table="Semantic Models",
            to_column="semanticmodel_id",
            from_table="Relationships",
            from_column="semanticmodel_id",
            from_cardinality="Many",
            to_cardinality="One",
            cross_filtering_behavior="Automatic",
            is_active=True
        )
        model.add_table(name=f'_Measures',description=f'Table to hold any measures.%%Other',hidden=False)
        
        print("_Measures table created")
        model.add_measure(
            table_name=f'_Measures',
            measure_name=f'Model Name',
            expression=f"IF(COUNTROWS(VALUES('Semantic Models'[Model]))>1 , \"Multiple Models\",MAX('Semantic Models'[Model]))",
            description=f'Measure to display selected model. Otherwise displays [Multiple Models]',
            hidden=False
        )
    print("Relationships added")
    

    #final refresh
    #refresh the newly created dataset
    print("Dataset refresh started...")
    fabric.refresh_dataset(workspace=workspace_name, dataset=semantic_model_name)
    print("Dataset refresh completed")
    
else:
    print("Use the Import mode template and connect to the selected lakehouse for the report. ")
    
print('All activity completed!')
# Out:
# StatementMeta(, 8bb55441-8bb4-44a2-bc86-fabbfe0394c1, 28, Finished, Available, Finished, False)
# The semantic model 'sem_ModelCatalog' exists in the workspace.
# THE SEMANTIC MODEL WILL BE REPLACED
# 🟢 The 'sem_ModelCatalog' semantic model was created within the 'amaser_dp700' workspace.
# ⌛ Refresh of the 'sem_ModelCatalog' semantic model within the 'amaser_dp700' workspace is in progress...
# 🟢 Refresh 'full' of the 'sem_ModelCatalog' semantic model within the 'amaser_dp700' workspace is complete.
# Created Semantic Model sem_ModelCatalog
# calculationitems
# dependencies
# expression
# hierarchies
# measurelist
# model
# partitions
# pbicolumns
# pbiroles
# pbitables
# relationships
# semanticmodel
# Table rename completed
# _Measures table created
# Relationships added
# Dataset refresh started...
# Dataset refresh completed
# All activity completed!
